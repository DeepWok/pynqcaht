# %%
from pynq import Overlay, allocate
from pynq.lib.merge import MergeIP

overlay = Overlay('/home/xilinx/jupyter_notebooks/ws/merge-test/mergeTest.bit') # Modify based on where you put your .bit

# %%
overlay?
# Should show two IP blocks: merge_v1_0_0, processing_system7_0

# %%
print(type(overlay.merge_v1_0_0))
# Should show <class 'pynq.lib.merge.MergeIP'>

# %%
a = [1,3,5,7,9]
b = [2,4,6,8]

# %%
result = overlay.merge_v1_0_0.merge(a,b) # modify "merge_v1_0_0" based on how you named the IP during creation
print(result)
